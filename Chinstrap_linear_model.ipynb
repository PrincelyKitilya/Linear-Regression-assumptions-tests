# %% [markdown]
# ## Analyzing the Chinstrap Penguins

# %%
#importing the correct pacakges
import pandas as pd
import seaborn as sns

#loading dataset 
penguins = sns.load_dataset("Penguins")

#Examining the first 5 rows
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
# Checking out how many species of Penguins there are 
print(penguins["species"].unique())
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']

# %%
# isolating the "Chinstrap" penguin species
chinstrap_penguins =penguins[penguins["species"] ==  "Chinstrap"]

# reseting the indexes of the chinstrap penguins
# .reset index method takes in two arguments inplace = boolean(True) and drop = boolean (True)
chinstrap_penguins.reset_index(inplace=True, drop=True)
chinstrap_penguins.head()
# Out:
#      species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Chinstrap  Dream            46.5           17.9              192.0
# 1  Chinstrap  Dream            50.0           19.5              196.0
# 2  Chinstrap  Dream            51.3           19.2              193.0
# 3  Chinstrap  Dream            45.4           18.7              188.0
# 4  Chinstrap  Dream            52.7           19.8              197.0
#
#    body_mass_g     sex
# 0       3500.0  FEMALE
# 1       3900.0    MALE
# 2       3650.0    MALE
# 3       3525.0  FEMALE
# 4       3725.0    MALE

# %%
# looking at the shape of the data 
chinstrap_penguins.shape
# Out:
# (68, 7)

# %%
# Settin up the model for construction 
# isolate the dependent and independent variables 
# we want to access bill_depth_mm and flipper_length_mm
ols_data = chinstrap_penguins[["bill_depth_mm", "flipper_length_mm"]]

# %%
# we are going to use the statsmodels library for our analysis
# we need to write a formula using these variables remember y always on the left side 
# y - dependent variable, x - independent variable
ols_formula = "flipper_length_mm ~ bill_depth_mm"

# %%
# constructing the model 
from statsmodels.formula.api import ols

#Building OLS and fitting model to data 
OLS = ols(formula=ols_formula, data=ols_data)
model = OLS.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      flipper_length_mm   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     33.48
# Date:                Tue, 11 Nov 2025   Prob (F-statistic):           2.16e-07
# Time:                        15:46:38   Log-Likelihood:                -215.62
# No. Observations:                  68   AIC:                             435.2
# Df Residuals:                      66   BIC:                             439.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# making model predictions and redisuals

#making predictions using the new model to obtain predicted values using the independent variable x

predictions = model.predict(chinstrap_penguins[["bill_depth_mm"]])
